# %% [markdown]
# <p align="center">
#   <img src="https://www.verifia.ca/assets/logo.png" width="160px" alt="VerifIA Logo"/><br>
#   <strong>© 2025 VerifIA. All rights reserved.</strong>
# </p>

# %% [markdown]
# ### VerifIA - Model Verification: House Pricing Prediction with CatBoost
#
# In this notebook we address a house pricing prediction problem using a CatBoost regression model. We tune the model with Bayesian hyperparameter optimization (using BayesSearchCV) on our training data. Next, we wrap the trained model with VerifIA’s CBModel wrapper and generate a domain configuration—using either AI-powered domain generation or loading from a YAML file—to verify that the model’s predictions adhere to the expected domain rules.

# %%
# !pip install requests
# !pip install scikit-optimize
# !pip install "../../dist/verifia-0.1.0-py3-none-any.whl[catboost, genflow]"

# %% [markdown]
# #### 0. Download Resources
#
# Before running any other cells, make sure you have all required resources:

# %%
# !curl -sL https://tinyurl.com/r6m2zk87 -o downloader.py

# %%
from downloader import download_resource
url = 'https://www.verifia.ca/assets/use-cases/'
download_resource(url+'data/house_price.csv', 
                  dest_dir='../data')
download_resource(url+'domains/house_price.yaml', 
                  dest_dir='../domains')
download_resource(url+'documents/house_price.zip', 
                  dest_dir='../documents/house_price')
# Out:
# {'extracted': True,
#  'files': ['articles/',
#   'articles/Housing Data.pdf',
#   'articles/National comprehensive housing market analysis.pdf',
#   'articles/United States Housing Market.pdf',
#   'articles/US Compared to Canada 2.pdf',
#   'articles/US Compared to Canada 3.pdf',
#   'data_report.pdf',
#   'domain_definition_meeting_notes.pdf',
#   'domain_definition_report.pdf',
#   'feature_selection.pdf',
#   'sensitivity_analysis_meeting_notes.pdf',
#   'sensitivity_analysis_report.pdf']}

# %% [markdown]
# #### 1. Importing Libraries and Setting Up
#
# We start by importing necessary libraries including Pandas, CatBoost, and modules from skopt and VerifIA.

# %%
# %load_ext autoreload
# %autoreload 2
import os
import getpass
import pandas as pd
import catboost as cb 
from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, DeltaYStopper
from verifia.models import CBModel, build_from_model_card
from verifia.verification.results import RulesViolationResult
from verifia.context.data import Dataset
from verifia.verification.verifiers import RuleConsistencyVerifier

# %% [markdown]
# #### 2. Data Loading
#
# We define constants such as the random seed, model directory paths, and the data file path. The house pricing dataset is loaded from a CSV file, with the target variable *price* separated from the remaining feature columns.

# %%
RAND_SEED = 0
MODELS_DIRPATH = "../models"
DATA_PATH = "../data/house_price.csv"
dataframe = pd.read_csv(DATA_PATH)
target_name = "price"
feature_names = set(dataframe.columns) - {target_name}

# %% [markdown]
# #### 3. Building the CatBoost Model Wrapper
#
# Using VerifIA’s `build_from_model_card`, we create a `CBModel` instance. This wrapper encapsulates essential metadata (model name, version, type, feature names, target name, and local directory) and will later be used to link our CatBoost model with the verification framework.

# %%
model_wrapper:CBModel = build_from_model_card({
    "name": "house_price",
    "version": "2",
    "type": "regression",
    "description": "model predicts the price of houses",
    "framework": "catboost",
    "feature_names": feature_names,
    "target_name": target_name,
    "local_dirpath": MODELS_DIRPATH
})

# %% [markdown]
# #### 4. Preparing the Dataset
#
# The loaded DataFrame is converted into a VerifIA `Dataset` object. This object organizes the data along with its feature and target information, and it automatically detects any categorical features. We then split the dataset into training and testing subsets (using an 80/20 split) for model tuning and final evaluation.

# %%
dataset = Dataset(dataframe, model_wrapper.target_name, 
                  model_wrapper.feature_names, 
                  model_wrapper.cat_feature_names)
train_dataset, test_dataset = dataset.split(0.8, RAND_SEED)

# %% [markdown]
# #### 5. Hyperparameter Tuning via Bayesian Optimization
#
# We define a search space for key CatBoost hyperparameters (including the number of iterations, learning rate, tree depth, L2 regularization, and border count).
# Using BayesSearchCV from skopt, we perform a Bayesian hyperparameter search over this space with a cross-validation scheme. Callback functions (such as DeltaYStopper and DeadlineStopper) monitor progress and limit runtime. The best hyperparameters are extracted from the search results.

# %%
cv_splits_count, max_trials, n_hparams_at_trial = 5, 10, 3
search_spaces = {
                "iterations": [500, 750, 1000],               # Number of boosting iterations.
                "learning_rate": [0.01, 0.05, 0.1, 0.3],      # Step size shrinkage used in updates.
                "depth": [3, 4, 5, 6, 7, 8],                  # Depth of the trees; deeper trees can capture more complex patterns.
                "l2_leaf_reg": [1e-3, 0.01, 0.1, 1, 10],      # L2 regularization on leaf weights to prevent overfitting.
                "border_count": [16, 32, 64, 128, 256],       # Number of splits for numerical features.
                }
hparams_tuner = BayesSearchCV(estimator=cb.CatBoostRegressor(verbose=0, allow_writing_files=False, random_state=RAND_SEED),                                    
                    search_spaces=search_spaces,                      
                    scoring='neg_mean_squared_error',                                  
                    cv=cv_splits_count,                               # number of splits for cross-validation            
                    n_iter=max_trials,                                # max number of trials
                    n_points=n_hparams_at_trial,                      # number of hyperparameter sets evaluated at the same time
                    iid=False,                                        # if not iid it optimizes on the cv score
                    return_train_score=False,                         
                    refit=False,                                      
                    optimizer_kwargs={'base_estimator': 'GP'},        # optmizer parameters: we use Gaussian Process (GP)
                    n_jobs=-1,                                      
                    random_state=RAND_SEED)

# %%
counter = 1
def onstep(res):
    global counter
    x0 = res.x_iters   # List of input points
    y0 = res.func_vals # Evaluation of input points
    print(f'Last eval #{counter}: {x0[-1]}', 
          f' - Score {y0[-1]:.3f}')
    print(f' - Best Score {res.fun:.3f}',
          f' - Best Args: {res.x}')
    counter += 1

overdone_control = DeltaYStopper(delta=0.0001)               # We stop if the gain of the optimization becomes too small
time_limit_control = DeadlineStopper(total_time=60 * 45)     # We impose a time limit (45 minutes)

callbacks=[overdone_control, time_limit_control, onstep]

# %%
X = train_dataset.feature_data()
y = train_dataset.target_data
cat_features = train_dataset.cat_feature_idxs
hparams_tuner.fit(X, y, cat_features=cat_features, callback=callbacks)

hparams_evals_count = len(hparams_tuner.cv_results_['params'])
best_score = hparams_tuner.best_score_
best_score_std = pd.DataFrame(hparams_tuner.cv_results_).iloc[hparams_tuner.best_index_].std_test_score
best_params = hparams_tuner.best_params_
print(f"candidates checked: {hparams_evals_count}, best CV score: {best_score:.3f}, best_score_std:{best_score_std:.3f}")
print(f"best_params: {best_params}")
# Out:
# Last eval #1: [16, 6, 500, 1, 0.3]  - Score 28644.007
#  - Best Score 21719.784  - Best Args: [64, 7, 750, 1, 0.3]
# Last eval #2: [64, 3, 500, 10, 0.1]  - Score 22801.408
#  - Best Score 21719.784  - Best Args: [64, 7, 750, 1, 0.3]
# Last eval #3: [32, 5, 500, 0.001, 0.1]  - Score 25357.934
#  - Best Score 21719.784  - Best Args: [64, 7, 750, 1, 0.3]
# Last eval #4: [16, 7, 750, 0.1, 0.3]  - Score 30418.996
#  - Best Score 21719.784  - Best Args: [64, 7, 750, 1, 0.3]
# candidates checked: 10, best CV score: -21719.784, best_score_std:5909.500
# best_params: OrderedDict([('border_count', 64), ('depth', 7), ('iterations', 750), ('l2_leaf_reg', 1), ('learning_rate', 0.3)])

# %% [markdown]
# #### 6. Training and Wrapping the Final CatBoost Model
#
# With the best hyperparameters identified, we create a CatBoostRegressor using these settings and train it on the full training data. The trained model is then assigned to the model wrapper. We evaluate its performance on the test dataset by computing a performance metric (e.g. mean squared error), ensuring the model’s predictive power is acceptable.

# %%
cb_model = cb.CatBoostRegressor(**best_params, allow_writing_files=False, random_state=RAND_SEED)
cb_model.fit(X, y, cat_features=cat_features)
model_wrapper.wrap_model(cb_model)
metric_name, metric_score = model_wrapper.calculate_predictive_performance(test_dataset)
print(f"Test Performance Metric : {metric_name}={metric_score}")
# Out:
# 0:	learn: 310.4541290	total: 129ms	remaining: 1m 36s
# 1:	learn: 269.2804704	total: 134ms	remaining: 50s
# 2:	learn: 239.2395798	total: 139ms	remaining: 34.6s
# 3:	learn: 220.5397192	total: 142ms	remaining: 26.6s
# 4:	learn: 205.3046589	total: 146ms	remaining: 21.7s
# 5:	learn: 195.3995721	total: 149ms	remaining: 18.5s
# 6:	learn: 186.9506973	total: 152ms	remaining: 16.2s
# 7:	learn: 181.7736535	total: 156ms	remaining: 14.4s
# 8:	learn: 174.6403285	total: 159ms	remaining: 13.1s
# 9:	learn: 168.3094718	total: 162ms	remaining: 12s
# 10:	learn: 165.0062718	total: 164ms	remaining: 11s
# 11:	learn: 162.6705773	total: 167ms	remaining: 10.3s
# 12:	learn: 158.1110517	total: 171ms	remaining: 9.68s
# 13:	learn: 155.7887147	total: 174ms	remaining: 9.17s
# 14:	learn: 153.3477049	total: 177ms	remaining: 8.68s
# 15:	learn: 151.8274951	total: 180ms	remaining: 8.27s
# 16:	learn: 149.9230527	total: 183ms	remaining: 7.9s
# 17:	learn: 147.6962719	total: 187ms	remaining: 7.61s
# 18:	learn: 146.1056777	total: 190ms	remaining: 7.32s
# 19:	learn: 145.1918947	total: 193ms	remaining: 7.05s
# 20:	learn: 144.1820413	total: 196ms	remaining: 6.8s
# 21:	learn: 143.0678791	total: 199ms	remaining: 6.59s
# 22:	learn: 141.9568623	total: 203ms	remaining: 6.43s
# 23:	learn: 141.4118624	total: 207ms	remaining: 6.25s
# 24:	learn: 140.4318938	total: 210ms	remaining: 6.09s
# 25:	learn: 136.8776189	total: 214ms	remaining: 5.96s
# 26:	learn: 135.7734750	total: 217ms	remaining: 5.81s
# 733:	learn: 37.4365430	total: 2.86s	remaining: 62.4ms
# 734:	learn: 37.4096196	total: 2.87s	remaining: 58.5ms
# 735:	learn: 37.3776134	total: 2.87s	remaining: 54.6ms
# 736:	learn: 37.3644844	total: 2.87s	remaining: 50.7ms
# 737:	learn: 37.3464421	total: 2.88s	remaining: 46.8ms
# 738:	learn: 37.2978585	total: 2.88s	remaining: 42.9ms
# 739:	learn: 37.2640659	total: 2.88s	remaining: 39ms
# 740:	learn: 37.2397821	total: 2.89s	remaining: 35.1ms
# 741:	learn: 37.2123568	total: 2.89s	remaining: 31.2ms
# 742:	learn: 37.1652958	total: 2.9s	remaining: 27.3ms
# 743:	learn: 37.1229873	total: 2.9s	remaining: 23.4ms
# 744:	learn: 37.0627121	total: 2.9s	remaining: 19.5ms
# 745:	learn: 37.0227398	total: 2.9s	remaining: 15.6ms
# 746:	learn: 36.9830520	total: 2.91s	remaining: 11.7ms
# 747:	learn: 36.9383156	total: 2.91s	remaining: 7.79ms
# 748:	learn: 36.9046423	total: 2.92s	remaining: 3.9ms
# 749:	learn: 36.8717129	total: 2.92s	remaining: 0us
# Test Performance Metric : RMSE=132.07602300726148

# %% [markdown]
# #### 7. Loading or Generating the Domain Configuration
#
# VerifIA allows you to create a domain configuration in two way. With the domain configuration available (either generated or loaded), we instantiate the `RuleConsistencyVerifier`. This verifier uses the domain rules and constraints to evaluate whether the model’s predictions on the test data are consistent with our domain knowledge.

# %% [markdown]
# ##### **Option A: Predefined Domain File:**
# A pre-defined YAML file (e.g., "house_price.yaml") can be loaded directly to provide the domain constraints and rules.

# %%
DOMAIN_PATH = f"../domains/house_price.yaml"
model_verifier = RuleConsistencyVerifier(DOMAIN_PATH)

# %% [markdown]
# ##### **Option B: AI-Powered Domain Generation:**
# VerifIA provides an AI-powered domain generation flow through the `DomainGenFlow` module. By supplying the training data, a directory of domain knowledge documents (in PDF format), and the model card details, a rich domain configuration is generated. This configuration contains variable definitions, constraints, and rules expected to hold true for the house pricing problem.

# %% [markdown]
# **Setup OpenAI and LangSmith Keys**
#
# Note that LangSmith is not needed, but it is helpful. If you do want to use LangSmith, after you sign up at the link above, make sure to set your environment variables to start logging traces.
#
# Accessing the OpenAI API requires an API key, which you can get by creating an account. Once you have a key you'll want to set it as an environment variable by running:

# %%
os.environ["LANGCHAIN_TRACING_V2"] = 'true'
os.environ["LANGCHAIN_ENDPOINT"] = 'https://api.smith.langchain.com'
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass(prompt='Your LANGCHAIN_API_KEY? ')
os.environ["OPENAI_API_KEY"] = getpass.getpass(prompt='Your OPENAI_API_KEY? ')
os.environ["USER_AGENT"] = 'my_agent'
os.environ["LANGCHAIN_PROJECT"] = 'VERIFIA_TEST'
os.environ["VERIFIA_GPT_NAME"] = 'gpt-4.1'

# %%
from verifia.generation import DomainGenFlow

DOMAIN_PDF_DIRPATH = "../documents/house_price"
domain_genflow = DomainGenFlow()
domain_genflow.load_ctx(dataframe=train_dataset.data, 
                        pdfs_dirpath=DOMAIN_PDF_DIRPATH,
                        model_card=model_wrapper.model_card.to_dict())
domain_cfg_dict = domain_genflow.run()
model_verifier = RuleConsistencyVerifier(domain_cfg_dict=domain_cfg_dict)
# Out:
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:verifia.generation.agents:Invoking agent for constraints_analysis
# INFO:verifia.generation.agents:Invoking agent for rules_analysis
# INFO:verifia.generation.agents:Invoking agent for variables_analysis
# INFO:verifia.generation.agents:Invoking agent for constraints_retriever
# INFO:verifia.generation.agents:Invoking agent for rules_retriever
# INFO:verifia.generation.agents:Invoking agent for variables_retriever
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:verifia.generation.graphs:Generating YAML with prompt:
# You are tasked with generating a final YAML specification for domain rules in a machine learning model validation project.
# You are provided with the following inputs:
#
# -------------------
# Variables Information:
#
# Here are the findings from the dataset analysis:
#
# 1) Feature Names:
# sqft_above, avg_nbhd_sqft_living15, sqft_lot, date_year, waterfront, bedrooms, built_since, view, date_month, has_been_renovated, sqft_living, bathrooms, grade, sqft_basement, avg_nbhd_sqft_lot15, condition, zipcode, floors, renovated_since
#
# Target Variable: price
#
# 2) Minimum and Maximum Values for Each Feature:
# - sqft_above: min 290, max 9410
# - avg_nbhd_sqft_living15: min 399, max 6110
# - sqft_lot: min 520, max 1,651,359
# - date_year: min 2014, max 2015
# - waterfront: min 0, max 1
# - bedrooms: min 0, max 33
# - built_since: min 0, max 115
# - view: min 0, max 4
# - date_month: min 1, max 12
# - has_been_renovated: min 0, max 1
# - sqft_living: min 290, max 13,540
# - bathrooms: min 0.0, max 8.0
# - grade: min 1, max 13
# - sqft_basement: min 0, max 4,820
# - avg_nbhd_sqft_lot15: min 651, max 871,200
# - condition: min 1, max 5
# - zipcode: min 98001, max 98199
# - floors: min 1.0, max 3.5
# - renovated_since: min 0.0, max 115.0
# - price: min 75.0, max 7,700.0
#
# 3) All Possible Values for Each Categorical Feature:
# There are no categorical features listed in your dataset.
#
# 4) Insignificant Variation for Each Feature:
# - sqft_above: 0.01
# - avg_nbhd_sqft_living15: 0.01
# - sqft_lot: 0.01
# - date_year: 0.01
# - waterfront: 0.05
# - bedrooms: 0.05
# - built_since: 0.01
# - view: 0.05
# - date_month: 0.05
# - has_been_renovated: 0.05
# - sqft_living: 0.01
# - bathrooms: 0.01
# - grade: 0.05
# - sqft_basement: 0.01
# - avg_nbhd_sqft_lot15: 0.01
# - condition: 0.05
# - zipcode: 0.05
# - floors: 0.05
# - renovated_since: 0.01
# - price (target variable): 0.02
#
# The target variable "price" has a nonzero insignificant variation, reflecting an acceptable margin of error for model predictions.
#
# Here is the extracted information from the PDFs:
#
# 1) Descriptions of each feature:
# - Properties are described by 20 features, including:
#   - Structural characteristics: square footage, number of bedrooms, number of bathrooms.
#   - Situational factors: waterfront location, neighborhood size metrics.
#   - Premium features: waterfront access, scenic views, extensive living areas, recent renovations, modern upgrades.
#   - Spacious living areas, including well-utilized basements.
#   - Modern updates in kitchens, bathrooms, and other key areas.
#   - Market and neighborhood comparisons: comparing a property with similar homes in the neighborhood.
#   - Age and renovation status: newer properties generally sell for more, but older homes with high-quality renovations can also command higher prices.
#
# 2) Name of the Target Variable:
# - The target variable is "price" (house price).
#
# Constraints Information:
#
# Here are potential constraints that the data inherently satisfies, based on the observed feature names and sample values:
#
# C1: sqft_lot >= sqft_living
# The lot size should be at least as large as the living area.
#
# C2: sqft_living = sqft_above + sqft_basement
# The total living area is the sum of the above-ground and basement areas.
#
# C3: sqft_basement >= 0
# Basement area cannot be negative.
#
# C4: sqft_above >= 0
# Above-ground area cannot be negative.
#
# C5: bedrooms >= 0
# Number of bedrooms cannot be negative.
#
# C6: bathrooms >= 0
# Number of bathrooms cannot be negative.
#
# C7: floors >= 1
# A house must have at least one floor.
#
# C8: 1 <= date_month <= 12
# Month values must be between 1 and 12.
#
# C9: 0 <= waterfront <= 1
# Waterfront is a binary indicator (0 or 1).
#
# C10: 0 <= has_been_renovated <= 1
# Renovation status is a binary indicator (0 or 1).
#
# C11: built_since >= 0
# Years since built cannot be negative.
#
# C12: renovated_since >= 0
# Years since renovation cannot be negative.
#
# C13: grade >= 1
# Grade must be at least 1.
#
# C14: condition >= 1
# Condition must be at least 1.
#
# C15: avg_nbhd_sqft_living15 >= 0
# Average neighborhood living area cannot be negative.
#
# C16: avg_nbhd_sqft_lot15 >= 0
# Average neighborhood lot size cannot be negative.
#
# C17: view >= 0
# View score cannot be negative.
#
# C18: zipcode > 0
# Zipcode must be a positive number.
#
# These constraints are directly inferred from the data structure and observed values, ensuring logical consistency within the dataset.
#
# Here are the extracted constraints specifying conditions the data must satisfy:
#
# C1: The number of bathrooms should be proportional to the number of bedrooms.
# C2: A property’s condition should align with its overall quality or grade.
# C3: Lot size must exceed living area.
# C4: Property dimensions should align with neighborhood norms.
# C5: Design features like the number of bedrooms, bathrooms, and renovations should follow logical patterns.
#
# These constraints are intended to ensure data consistency and realism for residential property datasets.
#
# Rules Information:
#
# R1:
#   premises: sqft_living: increase, sqft_above: increase, sqft_basement: increase
#   conclusion: price: increase
#   description: Larger total living area, including above-ground and basement square footage, is associated with higher property prices.
#
# R2:
#   premises: grade: increase
#   conclusion: price: increase
#   description: Higher grade, which typically reflects better construction quality and finish, leads to higher property prices.
#
# R3:
#   premises: condition: increase
#   conclusion: price: increase
#   description: Properties in better condition tend to command higher prices.
#
# R4:
#   premises: bedrooms: increase, bathrooms: increase
#   conclusion: price: increase
#   description: More bedrooms and bathrooms generally increase the value of a property.
#
# R5:
#   premises: built_since: decrease, renovated_since: decrease, has_been_renovated: eq(1)
#   conclusion: price: increase
#   description: Newer properties or those recently renovated tend to have higher prices.
#
# R6:
#   premises: waterfront: eq(1)
#   conclusion: price: increase
#   description: Properties with waterfront access are typically valued higher.
#
# R7:
#   premises: avg_nbhd_sqft_living15: increase, avg_nbhd_sqft_lot15: increase
#   conclusion: price: increase
#   description: Properties located in neighborhoods with larger average living and lot sizes tend to have higher prices, reflecting neighborhood desirability.
#
# R8:
#   premises: sqft_lot: increase
#   conclusion: price: increase
#   description: Larger lot sizes are generally associated with higher property prices.
#
# R9:
#   premises: view: increase
#   conclusion: price: increase
#   description: Properties with better views are typically priced higher.
#
# R10:
#   premises: floors: increase
#   conclusion: price: increase
#   description: Properties with more floors (stories) often have higher prices, possibly due to increased space or desirability.
#
# These rules summarize the main observed relationships between features and property price in the dataset.
#
# Here are domain rules describing relationships between features and the Target Variable (e.g., house price), extracted from the PDF content:
#
# R1: Higher grade (quality rating) and larger sqft_living (living area) interact to increase the target variable (price); the effect of quality multiplies the effect of area.
# R2: Temporal variables, such as sale dates or seasonality, can influence the target variable (price), with certain times of year potentially corresponding to higher or lower prices.
# R3: Categorical features like zipcode or condition categories, when encoded appropriately, can reveal location- or condition-based differences in the target variable (price).
# R4: The combination of a large lot size and the presence of a basement can have an interactive effect, potentially increasing the target variable (price) more than either feature alone.
#
# These rules describe how specific features or their interactions influence the target variable in the domain of real estate pricing.
# -------------------
#
# Using this information, produce a JSON object that strictly adheres to the schema below.
# Output only valid JSON (do not wrap it in triple backticks or code blocks) containing exactly the keys "variables", "constraints", and "rules".
#
# Schema:
#
# {
#   "variables": {
#     "<variable_name>": {
#       "description": "<meaning>",
#       "type": "<type>",          // Allowed values: "INT", "FLOAT", "CAT"
#       "range": [min_value, max_value],    // Required for INT and FLOAT types. Do NOT include "range" key for CAT type.
#       "values": ["Val1", "Val2", "Val3"],   // Required for CAT type. Do NOT include a "values" key for INT and FLOAT types.
#       "variation_limits": [min_value, max_value],  // Floats between 0 and 1. Do not use it for the Target Variable
#       "insignificant_variation": value             // Float between 0 and 1
#     },
#     ...
#   },
#   "constraints": {
#     "<constraint_name>": {
#       "description": "<meaning>",
#       "formula": "<formula>"     // A Python expression representing a condition
#     },
#     ...
#   },
#   "rules": {
#     "<rule_name>": {
#       "description": "<meaning>",
#       "premises": {
#          "<feature_name>": "<behavior>"   // Allowed behaviors: inc, dec, cst, noinc, nodec
#       },
#       "conclusion": {
#          "<target_name>": "<behavior>"     // Allowed behaviors: inc, dec, cst, noinc, nodec
#       }
#     },
#     ...
#   }
# }
#
# Explanation:
#
# - Constraints are conditions that must always hold true for the dataset. They represent requirements or restrictions on
#     the data.
#
# - Rules define relationships between features and the target variable and indicate how changes in one or more variables
#     may influence the target variable. Rules typically include a set of premises (conditions) and a conclusion
#     (the expected effect).
#
# Behavior abbreviations for variables:
# - inc: indicates that the variable is expected to increase.
# - dec: indicates that the variable is expected to decrease.
# - cst: indicates that the variable should remain constant.
# - noinc: indicates that the variable should not increase (i.e., it may decrease or remain constant).
# - nodec: indicates that the variable should not decrease (i.e., it may increase or remain constant).
#
# IMPORTANT:
# - Output only the JSON object (no extra text, explanation, or markdown).
# - Ensure that the keys are exactly "variables", "constraints", and "rules".
# - Do not include any inline comments in the output.
#
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %% [markdown]
# #### 8. Running the Rule Consistency Verifier
#
# The verifier is then connected to our wrapped CatBoost model and the test data. We run the verification using a Random Sampler ("RS") as the search algorithm with specified parameters (population size, number of iterations, and original seed size). This process explores the input space to uncover any instances where the model’s predictions deviate from the defined rules.

# %%
result:RulesViolationResult = model_verifier.verify(model_wrapper)\
                                            .on(test_dataset.data)\
                                            .using("RS")\
                                            .run(pop_size=4, max_iters=5, orig_seed_size=10)
# Out:
# INFO:verifia.verification.searchers:Searcher built with algorithm: RS
# INFO:verifia.verification.verifiers:Rows removed because they are out of domain: 2 out of 10
# INFO:verifia.verification.verifiers:In-Domain rows removed due to error > 13.900: 6 out of 8
# Processing Rules:   0%|          | 0/10 [00:00<?, ?it/s]INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R1 Violations: []
# Processing Original Inputs: 2it [00:00, 49.68it/s]
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R2 Violations: []
# Processing Original Inputs: 2it [00:00, 48.47it/s]
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R3 Violations: []
# Processing Original Inputs: 2it [00:00, 46.30it/s]
# Processing Rules:  30%|███       | 3/10 [00:00<00:00, 21.26it/s]INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R4 Violations: []
# Processing Original Inputs: 2it [00:00, 46.14it/s]
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R5 Violations: []
# Processing Original Inputs: 2it [00:00, 51.17it/s]
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: [189.74661337 214.26119327]
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: [ 73.24480524 125.9892426 ]
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: [136.96409197  55.31295363  75.9817316   20.17213766]
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: [165.14264291 159.53094397]
# INFO:verifia.verification.verifiers:Detected Rule R6 Violations: [ 12.23540978 125.15098738 257.34384064  39.14937528]
# Processing Original Inputs: 2it [00:00, 43.52it/s]
# Processing Rules:  60%|██████    | 6/10 [00:00<00:00, 21.19it/s]INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [55.78245564 14.39705725]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [66.75538193 64.73948379 35.72480551]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [39.54330428 21.4208543 ]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [36.57039839 50.25372779 56.27326267]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [135.05296984 119.2281217  210.29986798  43.23938097]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [45.46672631 90.84989183 84.7668255 ]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [ 93.27142823 147.03167445  96.98219574 114.12915562]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [ 16.13324265 108.66244352 197.71627358]
# INFO:verifia.verification.verifiers:Detected Rule R7 Violations: [186.3069423   17.48460575  38.64223631]
# Processing Original Inputs: 2it [00:00, 21.46it/s]
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: [31.73298748]
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: [23.492293   27.36156785]
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: [28.22528868]
# INFO:verifia.verification.verifiers:Detected Rule R8 Violations: []
# Processing Original Inputs: 2it [00:00, 36.37it/s]
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R9 Violations: []
# Processing Original Inputs: 2it [00:00, 49.47it/s]
# Processing Rules:  90%|█████████ | 9/10 [00:00<00:00, 17.74it/s]INFO:verifia.verification.verifiers:Detected Rule R10 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: [83.40073117]
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: []
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: [48.25456681 87.61944971]
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: [  1.34932257 113.6162889   76.72667849 122.93519611]
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: [196.20055587 244.06750987  62.17302302]
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: [59.24107626 65.46945275]
# INFO:verifia.verification.verifiers:Detected Rule R10 Violations: [ 41.48662342  49.31548285  40.03481792 165.61332303]
# Processing Original Inputs: 2it [00:00, 42.29it/s]
# Processing Rules: 100%|██████████| 10/10 [00:00<00:00, 18.60it/s]
# INFO:verifia.verification.results:Original data saved to .verifia\house_price-2\run_Z7eAI0u2\data\originals.csv
# INFO:verifia.verification.results:Inputs inconsistent with rule R6 saved to .verifia\house_price-2\run_Z7eAI0u2\data\R6_inconsistent_data.csv
# INFO:verifia.verification.results:Inputs inconsistent with rule R7 saved to .verifia\house_price-2\run_Z7eAI0u2\data\R7_inconsistent_data.csv
# INFO:verifia.verification.results:Inputs inconsistent with rule R8 saved to .verifia\house_price-2\run_Z7eAI0u2\data\R8_inconsistent_data.csv
# INFO:verifia.verification.results:Inputs inconsistent with rule R10 saved to .verifia\house_price-2\run_Z7eAI0u2\data\R10_inconsistent_data.csv
# INFO:verifia.verification.results:Summary saved to .verifia\house_price-2\run_Z7eAI0u2\_summary.json

# %% [markdown]
# #### 9. Saving the Verification Report and Model Artifacts
#
# Finally, the verification results are saved as an HTML report, which provides a detailed summary of rule compliance and any detected inconsistencies. Additionally, we save the trained CatBoost model and its model card configuration for future reference and reproducibility.

# %%
result.save_as_html("../reports/house_price.html")
# Out:
# INFO:verifia.verification.results:HTML report saved to ..\reports\house_price.html

# %%
model_wrapper.save_model()
model_wrapper.save_model_card("../models/house_price.yaml")
# Out:
# INFO:verifia.models.base:Default model file path constructed: ../models\house_price-2.cb
# INFO:verifia.models.cb:Model saved successfully to ..\models\house_price-2.cb
# INFO:verifia.models.base:Model card saved to ../models/house_price.yaml
